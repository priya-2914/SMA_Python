# %% [markdown]
# OOPS - Oject Oriented Programming

# %% [markdown]
# #Class:
# A class is a collection of objects. Classes are blueprints for creating objects. A class defines a set of attributes and methods that the created objects (instances) can have. Some points on Python class:
#
# Classes are created by keyword class.
# Attributes are the variables that belong to a class.
# Attributes are always public and can be accessed using the dot (.) operator. Example: Myclass.Myattribute

# %%
#Creating a class:
class Dog:
    species = "Canine"  # Class attribute

    def __init__(self, name, age):
        self.name = name  # Instance attribute
        self.age = age  # Instance attribute

# %% [markdown]
# Explanation:
#
# class Dog: creates a class named Dog, which acts as a blueprint for dog objects.
#
# species is a class attribute, meaning it is shared by all instances of the class.
#
# #__init__() is a constructor method that runs automatically when a new object is created. It is used to initialize object data.
#
# #self refers to the current object, allowing each object to store and access its own data.
#
# self.name and self.age are instance attributes, unique to each Dog object created from the class.
#
# It does not have to be named self, you can call it whatever you like, but it has to be the first parameter of any method in the class:

# %% [markdown]
# #Objects
# An Object is an instance of a Class. It represents a specific implementation of the class and holds its own data. An object consists of:
#
# State: It is represented by the attributes and reflects the properties of an object.
#
# Behavior: It is represented by the methods of an object and reflects the response of an object to other objects.
#
# Identity: It gives a unique name to an object and enables one object to interact with other objects.

# %%
#creating a Object
class Dog:
    species = "Canine"  # Class attribute

    def __init__(self, name, age):
        self.name = name  # Instance attribute
        self.age = age  # Instance attribute

# Creating an object of the Dog class
dog1 = Dog("Buddy", 3)

print(dog1.name)
print(dog1.species)
# Out:
# Buddy
# Canine

# %%
# What if the class and instance have same attributes?
''' Python first checks the object → then the class
This is called instance attribute overrides class attribute.'''
class Dog:
    species = "Canine"   # class attribute

    def __init__(self, name, species):
        self.name = name
        self.species = species   # instance attribute (same name)

dog1 = Dog("Buddy", "Husky")

print(dog1.species)
print(Dog.species)
# Out:
# Husky
# Canine

# %%
class CoffeeMachine:
    def make_coffee(self):
        self.__boil_water()
        self.__grind_beans()
        self.__mix()
        print("Coffee ready!")

    def __boil_water(self):
        print("Boiling water")

    def __grind_beans(self):
        print("Grinding beans")

    def __mix(self):
        print("Mixing everything")

# %%
c = CoffeeMachine()
c.make_coffee()
# Out:
# Boiling water
# Grinding beans
# Mixing everything
# Coffee ready!

# %% [markdown]
# # Class Methods
# Methods are functions that belong to a class. They define the behavior of objects created from the class.
#
# Note: All methods must have self as the first parameter.

# %%
class Person:
  def __init__(self, name):
    self.name = name

  def greet(self):
    print("Hello, my name is " + self.name)

p1 = Person("Emil")
p1.greet()
# Out:
# Hello, my name is Emil

# %%
#Methods with Parameters
class Calculator:
  def add(self, a, b):
    return a + b

  def multiply(self, a, b):
    return a * b

calc = Calculator()
print(calc.add(5, 3))
print(calc.multiply(4, 7))
# Out:
# 8
# 28

# %%
#Methods Modifying Properties
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def celebrate_birthday(self):
    self.age += 1
    print(f"Happy birthday! You are now {self.age}")

p1 = Person("Linus", 25)
p1.celebrate_birthday()
p1.celebrate_birthday()
# Out:
# Happy birthday! You are now 26
# Happy birthday! You are now 27

# %% [markdown]
# #The __str__() Method : The __str__() method is a special method that controls what is returned when the object is printed:

# %%
class Person:
  def __init__(self,name,age):
    self.name=name
    self.age=age
  def __str__(self):
    return f"{self.name} is {self.age} years old"
p1=Person("priya",24)
print(p1)
# Out:
# priya is 24 years old

# %%
class Rectangle:
  def __init__(self,width,height):
    self.width=width
    self.height=height
  def area(self):
    return self.width*self.height
r1 = Rectangle(5,3)
r1.area()
# Out:
# 15

# %% [markdown]
# #Inheritance
# Inheritance allows us to define a class that inherits all the methods and properties from another class.
#
# Parent class is the class being inherited from, also called base class.
#
# Child class is the class that inherits from another class, also called derived class.
#
# With inheritance:
#
# Code becomes reusable
#
# Programs become cleaner
#
# Easier to maintain
#
# Models real-world relationships naturally

# %%
# Basic Example
class Animal:
  def eat(self):
    print("This animal eats food")
class Dog(Animal):
  def bark(self):
    print("Dog barks")

d = Dog()
d.eat()   # Inherited from Animal
d.bark()
# Out:
# This animal eats food
# Dog barks

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def display_info(self):
        print(f"Name: {self.name}")
        print(f"Salary: {self.salary}")

class DataScientist(Employee):
    def analyze_data(self):
        print("Analyzing data...")

class Manager(Employee):
    def manage_team(self):
        print("Managing team...")

ds = DataScientist("Priya", 90000)
ds.display_info()
ds.analyze_data()

m = Manager("Rahul", 120000)
m.display_info()
m.manage_team()
# Out:
# Name: Priya
# Salary: 90000
# Analyzing data...
# Name: Rahul
# Salary: 120000
# Managing team...

# %% [markdown]
# #Constructor Inheritance (super())

# %%
class Employee:
    def __init__(self, name):
        self.name = name

class DataScientist(Employee):
    def __init__(self, name, skills):
        super().__init__(name)   # Call parent constructor
        self.skills = skills

    def show(self):
        print(self.name, self.skills)

ds = DataScientist("Priya", ["Python", "ML"])
ds.show()
# Out:
# Priya ['Python', 'ML']

# %% [markdown]
# Differences Between super() and Direct Call
#
# Syntax	          super().__init__(...)	    &     ParentClass.__init__(...)

# %% [markdown]
# Imagine this hierarchy:
#
# A is the top parent
#
# B and C inherit from A
#
# D inherits from both B and C
#
# Using super() (Python’s MRO)
#
# Python doesn’t just look at the immediate parent — it follows the Method Resolution Order (MRO):
#
# D → B → C → A
#
# If D calls super().method(), Python goes to B first, then C, then A, in order.

# %%
class A:
    def show(self):
        print("A")

class B(A):
    def show(self):
        print("B")
        super().show()

class C(A):
    def show(self):
        print("C")
        super().show()

class D(B, C):
    def show(self):
        print("D")
        super().show()

d = D()
d.show()
# Out:
# D
# B
# C
# A

# %%
class A:
    def show(self):
        print("A")

class B(A):
    def show(self):
        print("B")
        super().show()

class C(A):
    def show(self):
        print("C")
        super().show()

class D(B, C):
    def show(self):
        print("D")
        B.show(self)
        C.show(self)

d = D()
d.show()
# Out:
# D
# B
# C
# A
# C
# A

# %% [markdown]
# super() → Python follows MRO, avoids repeated calls, handles complex hierarchies.
#
# Direct class call → Works for simple cases, but can lead to duplicates or skipped classes in multiple inheritance.

# %% [markdown]
# #Types of Inheritance
#
# 1.Single Inheritance
#
# One child, one parent.
#
# Animal → Dog

# %%
#2.Multiple Inheritance
class Father:
    def skills(self):
        print("Gardening")

class Mother:
    def skills(self):
        print("Cooking")

class Child(Father, Mother):
    pass

c = Child()
c.skills() #Python follows something called MRO (Method Resolution Order).It checks from left to right.
# Out:
# Gardening

# %%
# we can check order using:
print(Child.mro())
# Out:
# [<class '__main__.Child'>, <class '__main__.Father'>, <class '__main__.Mother'>, <class 'object'>]

# %%
#3.Multilevel Inheritance
class Grandparent:
    def house(self):
        print("Big house")

class Parent(Grandparent):
    pass

class Child(Parent):
    pass

c = Child()
c.house()
# Out:
# Big house

# %% [markdown]
# Hierarchical Inheritance
#
# One parent → Multiple children
#
#         Animal
#        /      \
#      Dog      Cat

# %% [markdown]
# #Method Overriding

# %%
class Animal:
    def sound(self):
        print("Animal makes sound")

class Dog(Animal):
    def sound(self):
        print("Dog barks")

d = Dog()
d.sound()
# Out:
# Dog barks

# %%
'''Parent method is overridden.

If you still want parent version:'''

class Dog(Animal):
    def sound(self):
        super().sound()
        print("Dog barks")
d = Dog()
d.sound()
# Out:
# Animal makes sound
# Dog barks

# %% [markdown]
# # isinstance() & issubclass()

# %%
print(isinstance(ds, Employee))   # True
print(issubclass(DataScientist, Employee))  # True
# Out:
# True
# True
