# %% [markdown]
# # Polymorphism
# Polymorphism allows the same method or interface to behave differently depending on the object that calls it.

# %%
class Payment:
    def pay(self, amount):
        pass
class CreditCard(Payment):
    def pay(self, amount):
        print("Paid", amount, "using Credit Card")

class PayPal(Payment):
    def pay(self, amount):
        print("Paid", amount, "using PayPal")

payments = [CreditCard(), PayPal()]

for p in payments:
    p.pay(100)
# Out:
# Paid 100 using Credit Card
# Paid 100 using PayPal

# %% [markdown]
# Same function:
#
# pay()
#
# Different behavior depending on object.
#
# That is polymorphism.

# %% [markdown]
# #Encapsulation
#
# Encapsulation is about protecting data inside a class.
#
# It means keeping data (properties) and methods together in a class, while controlling how the data can be accessed from outside the class.
#
# This prevents accidental changes to your data and hides the internal details of how your class works.

# %%
'''Private Properties
In Python, you can make properties private by using a double underscore __ prefix:'''
#Create a private class property named __age:

class Person:
  def __init__(self, name, age):
    self.name = name
    self.__age = age # Private property

p1 = Person("Emil", 25)
print(p1.name)
print(p1.__age) # This will cause an error
# Out:
# Emil
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_640/2255687168.py in <cell line: 0>()
#      10 p1 = Person("Emil", 25)
#      11 print(p1.name)
# ---> 12 print(p1.__age) # This will cause an error
#
# AttributeError: 'Person' object has no attribute '__age'

# %% [markdown]
# Note: Private properties cannot be accessed directly from outside the class.

# %% [markdown]
# #Get Private Property Value
# To access a private property, you can create a getter method:

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.__age = age

  def get_age(self):
    return self.__age

p1 = Person("Tobias", 25)
print(p1.get_age())
# Out:
# 25

# %% [markdown]
# #Set Private Property Value
# To modify a private property, you can create a setter method.
#
# The setter method can also validate the value before setting it:

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.__age = age

  def get_age(self):
    return self.__age

  def set_age(self, age):
    if age > 0:
      self.__age = age
    else:
      print("Age must be positive")

p1 = Person("Tobias", 25)
print(p1.get_age())

p1.set_age(26)
print(p1.get_age())
# Out:
# 25
# 26

# %% [markdown]
# Encapsulation provides several benefits:
#
# Data Protection: Prevents accidental modification of data
# Validation: You can validate data before setting it
# Flexibility: Internal implementation can change without affecting external code
# Control: You have full control over how data is accessed and modified

# %%
class Student:
  def __init__(self, name):
    self.name = name
    self.__grade = 0

  def set_grade(self, grade):
    if 0 <= grade <= 100:
      self.__grade = grade
    else:
      print("Grade must be between 0 and 100")

  def get_grade(self):
    return self.__grade

  def get_status(self):
    if self.__grade >= 60:
      return "Passed"
    else:
      return "Failed"

student = Student("Emil")
student.set_grade(85)
print(student.get_grade())
print(student.get_status())
# Out:
# 85
# Passed

# %% [markdown]
# #Protected Properties
# Python also has a convention for protected properties using a single underscore _ prefix:

# %%
class Person:
  def __init__(self, name, salary):
    self.name = name
    self._salary = salary # Protected property

p1 = Person("Linus", 50000)
print(p1.name)
print(p1._salary) # Can access, but shouldn't
# Out:
# Linus
# 50000

# %% [markdown]
# #Private methods

# %%
class Calculator:
  def __init__(self):
    self.result = 0

  def __validate(self, num):
    if not isinstance(num, (int, float)):
      return False
    return True

  def add(self, num):
    if self.__validate(num):
      self.result += num
    else:
      print("Invalid number")

calc = Calculator()
calc.add(10)
calc.add(5)
print(calc.result)
#calc.__validate(5) # This would cause an error
# Out:
# 15

# %% [markdown]
# #Just like private properties with double underscores, private methods cannot be called directly from outside the class. The __validate method can only be used by other methods inside the class.

# %% [markdown]
# #Name Mangling
# Name mangling is how Python implements private properties and methods.
#
# When you use double underscores __, Python automatically renames it internally by adding _ClassName in front.
#
# For example, __age becomes _Person__age.

# %%
class Student:
  def __init__(self,name,age):
    self.name=name
    self.__age=age

p1=Student("Emil",25)
print(p1.name)
# This is how Python mangles the name:
print(p1._Person__age) # Not recommended!
# Out:
# Emil
# 25

# %% [markdown]
# #While you can access private properties using the mangled name, it's not recommended. It defeats the purpose of encapsulation.

# %% [markdown]
# #Abstraction
# Data abstraction means showing only the essential features and hiding the complex internal details. Technically, in Python abstraction is used to hide the implementation details from the user and expose only necessary parts, making the code simpler and easier to interact with.

# %% [markdown]
# Python implements abstraction using the ABC module.
#
# ABC stands for:
#
# Abstract Base Class
#
# We use:
#
# from abc import ABC, abstractmethod
#
# ABC → used to create an abstract class
#
# abstractmethod → defines a method that must be implemented by child classes

# %%
#basic Example
from abc import ABC, abstractmethod

class Shape(ABC):

    @abstractmethod
    def area(self):
        pass

# %% [markdown]
# Here:
#
# Shape is an abstract class
#
# area() is an abstract method
#
# This means:
#
# Any class that inherits Shape must define area().

# %%
class Rectangle(Shape):

    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# %%
class Circle(Shape):

    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius

# %%
r = Rectangle(5, 4)
c = Circle(3)

print(r.area())
print(c.area())
# Out:
# 20
# 28.259999999999998

# %% [markdown]
# Important Rule
#
# You cannot create an object of an abstract class.

# %%
#Example:

s = Shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_640/2619389512.py in <cell line: 0>()
#       1 #Example:
#       2
# ----> 3 s = Shape()
#
# TypeError: Can't instantiate abstract class Shape without an implementation for abstract method 'area'

# %% [markdown]
# #Why We Use Abstraction
#
# Abstraction helps to:
#
# #1. Enforce Structure
#
# All subclasses must implement required methods.
#
# Example:
#
# Shape → must have area()
# Payment → must have pay()
# Animal → must have make_sound()
#
# #2.Hide Implementation Details
#
# Users interact with methods but do not see internal logic.
#
# Example:
#
# car.start()
#
# You don't know how the engine starts internally.
#
# #3. Improve Code Consistency
#
# In large systems with many developers, abstraction ensures everyone follows the same interface.
